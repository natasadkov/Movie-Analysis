# %% [markdown]
# ***
# ## DA 320
#
# #### Midterm Assignment: Movie Analysis from Metacritic by using Python, regex, mongoDB
# #### Student: Natalia Sadkov
# #### Teacher: Professor T.Spence
# #### Date: November 9, 2022
#
# ***

# %%
# import libraries
import re
import urllib3
import certifi

# %% [markdown]
# ***
# #### Setup regular expressions for tilte, release date, description, metascore, image url
# ***

# %%
# constract all regular expressions
title_regex=re.compile(r"class=\"title\"><h3>(.+)</h3>")
date_regex=re.compile(r"class=\"clamp-details\">\s+<span>(.+)</span>")
description_regex=re.compile(r"<div class=\"summary\">\s*([\S\s]+?)\s*</div>")
score_regex = re.compile(r"<span class=\"title\">Metascore:</span>\s+<a class=\"metascore_anchor\" href=\"/movie/.*?/critic-reviews\">\s+<div class=\"metascore_w large movie .+\">(.*?)</div>")
image_regex = re.compile(r"<a href=\"/movie/.*\"><img src=\"(.*)\" alt=\"")

# Construct an HTTP pool for connection
http=urllib3.PoolManager(ca_certs=certifi.where())

# %% [markdown]
# ***
# #### Connect to mongoDB
# ***

# %%
import json
import pymongo
import certifi
# retrieve creditials to connect MongoDB
with open('/Users/natasha/Desktop/Fall 2022/DA320/Password MongoDB/credentials.json') as f:
    data = json.load(f)
    secret_key = data['mongodb']

# Connect to the database using known good certificates
client = pymongo.MongoClient(secret_key, tlsCAFile=certifi.where())
# Fetch the database named "DA-320"
da320_database = client['DA-320']

# Within the database we have "collections". Think of them as tables in SQL.
metacritic_data = da320_database['metacritic']

# %% [markdown]
# ***
# #### Web scraping function
# ***

# %%
import pandas as pd
#retrive a list of movies from a particular year and page of Metacritic
def metacritic_scraper (year:int,page:int) -> pd.DataFrame:
    #fetch the webpage
   url = f"https://www.metacritic.com/browse/movies/score/metascore/year/filtered?year_selected={year}&sort=desc&view=detailed&page={page}"
   # Construct python request pool
   response = http.request('GET',url,headers={'User-Agent':'Mozilla/5.0'})
   datastring = str(response.data, "utf-8")

   #execute all regular expression
   titles = title_regex.findall(datastring)
   dates = date_regex.findall(datastring)
   descriptions = description_regex.findall(datastring)
   scores = score_regex.findall(datastring)
   images = image_regex.findall(datastring)
   #return unified collection  
   print("title: " , len(titles), "date: " , len(dates), "description: " , len(descriptions), "score: " , len(scores), "image: " , len(images))
   dataset = {"title": titles, "date": dates, "description": descriptions, "score": scores, "image":images}
   return pd.DataFrame(dataset)

# %% [markdown]
# ***
# #### Loop through years and pages
# ***

# %%
import re
import time

#CVS file
for year in range(2000,2023):
   page=0
   print(f"Collection date for {year} page {page}.....")

   #retry a page multiple times
   while True:
      data = metacritic_scraper(year,page)

      #stop when we reach a page with zero rows
      if len(data) == 0:
         break

      #conver the dataframe into a list of movies to insert into Mongo DB
      movies_to_insert =[]
      for row in data.itertuples():
         movie = {
            "title": row.title,
            "release_date": row.date,
            "description": row.description,
            "metascore": row.score,
            "image_url": row.image,
         }
         movies_to_insert.append(movie)
         
      #insert resords into MongoDB
      print(f"Inserting{len(movies_to_insert)} moview for year {year} page {page}")
      metacritic_data.insert_many(movies_to_insert)
      page = page+1
# Out:
# Collection date for 2000 page 0.....
# title:  100 date:  100 description:  100 score:  100 image:  100
# Inserting100 moview for year 
# title:  100 date:  100 description:  100 score:  100 image:  100
# Inserting100 moview for year 2015 page 0
# title:  100 date:  100 description:  100 score:  100 image:  100
# Inserting100 moview for year 2015 page 1
# title:  100 date:  100 description:  100 score:  100 image:  100
# Inserting100 moview for year 2015 page 2
# title:  100 date:  100 description:  100 score:  100 image:  100
# Inserting100 moview for year 2015 page 3
# title:  100 date:  100 description:  100 score:  100 image:  100
# Inserting100 moview for year 2015 page 4
# title:  100 date:  100 description:  100 score:  100 image:  100
# Inserting100 moview for year 2015 page 5
# title:  40 date:  40 description:  40 score:  40 image:  40
# Inserting40 moview for year 2015 page 6
# title:  0 date:  0 description:  0 score:  0 image:  0
# Collection date for 2016 page 0.....
# title:  100 date:  100 description:  100 score:  100 image:  100
# Inserting100 moview for year 2016 page 0
# title:  100 date:  100 description:  100 score:  100 image:  100
# Inserting100 moview for year 2016 page 1
# title:  100 date:  100 description:  100 score:  100 image:  100
# Inserting100 moview for year 2016 page 2
# title:  100 date:  100 description:  100 score:  100 image:  100
# Inserting100 moview for year 2016 page 3
# title:  100 date:  100 description:  100 score:  100 image:  100
# Inserting100 moview for year 2016 page 4
# title:  100 date:  100 description:  100 score:  100 image:  100
# Inserting100 moview for year 2016 page 5
# title:  13 date:  13 description:  13 score:  13 image:  13
# Inserting13 moview for year 2016 page 6
# title:  0 date:  0 description:  0 score:  0 image:  0
# Collection date for 2017 page 0.....
# title:  100 date:  100 description:  100 score:  100 image:  100
# Inserting100 moview for year 2017 page 0
# title:  100 date:  100 description:  100 score:  100 image:  100
# Inserting100 moview for year 2017 page 1
# title:  100 date:  100 description:  100 score:  100 image:  100
# Inserting100 moview for year 2017 page 2
# title:  100 date:  100 description:  100 score:  100 image:  100
# Inserting100 moview for year 2017 page 3
# title:  100 date:  100 description:  100 score:  100 image:  100
# Inserting100 moview for year 2017 page 4
# title:  100 date:  100 description:  100 score:  100 image:  100
# Inserting100 moview for year 2017 page 5
# title:  13 date:  13 description:  13 score:  13 image:  13
# Inserting13 moview for year 2017 page 6
# title:  0 date:  0 description:  0 score:  0 image:  0
# Collection date for 2018 page 0.....
# title:  100 date:  100 description:  100 score:  100 image:  100
# Inserting100 moview for year 2018 page 0
# title:  100 date:  100 description:  100 score:  100 image:  100
# Inserting100 moview for year 2018 page 1
# title:  100 date:  100 description:  100 score:  100 image:  100
# Inserting100 moview for year 2018 page 2
# title:  100 date:  100 description:  100 score:  100 image:  100
# Inserting100 moview for year 2018 page 3
# title:  100 date:  100 description:  100 score:  100 image:  100
# Inserting100 moview for year 2018 page 4
# title:  100 date:  100 description:  100 score:  100 image:  100
# Inserting100 moview for year 2018 page 5
# title:  11 date:  11 description:  11 score:  11 image:  11
# Inserting11 moview for year 2018 page 6
# title:  0 date:  0 description:  0 score:  0 image:  0
# Collection date for 2019 page 0.....
# title:  100 date:  100 description:  100 score:  100 image:  100
# Inserting100 moview for year 2019 page 0
# title:  100 date:  100 description:  100 score:  100 image:  100
# Inserting100 moview for year 2019 page 1
# title:  100 date:  100 description:  100 score:  100 image:  100
# Inserting100 moview for year 2019 page 2
# title:  100 date:  100 description:  100 score:  100 image:  100
# Inserting100 moview for year 2019 page 3
# title:  100 date:  100 description:  100 score:  100 image:  100
# Inserting100 moview for year 2019 page 4
# title:  69 date:  69 description:  69 score:  69 image:  69
# Inserting69 moview for year 2019 page 5
# title:  0 date:  0 description:  0 score:  0 image:  0
# Collection date for 2020 page 0.....
# title:  100 date:  100 description:  100 score:  100 image:  100
# Inserting100 moview for year 2020 page 0
# title:  100 date:  100 description:  100 score:  100 image:  100
# Inserting100 moview for year 2020 page 1
# title:  100 date:  100 description:  100 score:  100 image:  100
# Inserting100 moview for year 2020 page 2
# title:  100 date:  100 description:  100 score:  100 image:  100
# Inserting100 moview for year 2020 page 3
# title:  100 date:  100 description:  100 score:  100 image:  100
# Inserting100 moview for year 2020 page 4
# title:  43 date:  43 description:  43 score:  43 image:  43
# Inserting43 moview for year 2020 page 5
# title:  0 date:  0 description:  0 score:  0 image:  0
# Collection date for 2021 page 0.....
# title:  100 date:  100 description:  100 score:  100 image:  100
# Inserting100 moview for year 2021 page 0
# title:  100 date:  100 description:  100 score:  100 image:  100
# Inserting100 moview for year 2021 page 1
# title:  100 date:  100 description:  100 score:  100 image:  100
# Inserting100 moview for year 2021 page 2
# title:  100 date:  100 description:  100 score:  100 image:  100
# Inserting100 moview for year 2021 page 3
# title:  100 date:  100 description:  100 score:  100 image:  100
# Inserting100 moview for year 2021 page 4
# title:  39 date:  39 description:  39 score:  39 image:  39
# Inserting39 moview for year 2021 page 5
# title:  0 date:  0 description:  0 score:  0 image:  0
# Collection date for 2022 page 0.....
# title:  100 date:  100 description:  100 score:  100 image:  100
# Inserting100 moview for year 2022 page 0
# title:  100 date:  100 description:  100 score:  100 image:  100
# Inserting100 moview for year 2022 page 1
# title:  100 date:  100 description:  100 score:  100 image:  100
# Inserting100 moview for year 2022 page 2
# title:  100 date:  100 description:  100 score:  100 image:  100
# Inserting100 moview for year 2022 page 3
# title:  78 date:  78 description:  78 score:  78 image:  78
# Inserting78 moview for year 2022 page 4
# title:  0 date:  0 description:  0 score:  0 image:  0

# %% [markdown]
# ***
# #### Retrieving metacritic collection from MongoDB
# ***

# %%
import json
import pymongo
import certifi
import pandas

# Retrieve credentials for MongoDB server from my credentials file
with open('/Users/natasha/Desktop/Fall 2022/DA320/Password MongoDB/credentials.json') as f:
   data = json.load(f)
   secret_key = data['mongodb']

# Fetch the database named "DA-320"

client = pymongo.MongoClient (secret_key, tlsCAFile=certifi.where())
da320_database = client['DA-320']
metactritic_data = da320_database['metacritic']
metacritic = pandas.DataFrame(metacritic_data.find())

metacritic.head()
# Out:
#                         _id                           title  \
# 0  636c8f610b81c439d92a0acc  Crouching Tiger, Hidden Dragon
# 1  636c8f610b81c439d92a0acd                           Yi Yi
# 2  636c8f610b81c439d92a0ace                    Beau Travail
# 3  636c8f610b81c439d92a0acf                   Almost Famous
# 4  636c8f610b81c439d92a0ad0                     Chicken Run
#
#          release_date                                        description  \
# 0    December 8, 2000  In 19th century China, a magical sword given b...
# 1     October 6, 2000  This film portrays life through portraits of t...
# 2      March 31, 2000  The soldiers of a small French Foreign Legion ...
# 3  September 13, 2000  In the 1970's, a high school boy (Fugit) is gi...
# 4       June 21, 2000  A claymation spoof of classic prison-camp flic...
#
#   metascore                                          image_url
# 0        94  https://static.metacritic.com/images/products/...
# 1        93  https://static.metacritic.com/images/products/...
# 2        91  https://static.metacritic.com/images/products/...
# 3        90  https://static.metacritic.com/images/products/...
# 4        88  https://static.metacritic.com/images/products/...

# %% [markdown]
# ***
# #### Transforming data in Pandas
# ***

# %%
# Convert release dates into actual dates and gather year/month
metacritic.release_date = pandas.to_datetime (metacritic.release_date)
metacritic['year'] = metacritic.release_date.dt.year
metacritic['month'] = metacritic.release_date.dt.month
metacritic.metascore = pandas.to_numeric(metacritic.metascore)
metacritic.head()

# %% [markdown]
# ***
# ### Comparing histograms by keywords Sad and Happy for 2000-2022
# ***

# %%
from matplotlib import pyplot
from matplotlib.ticker import FormatStrFormatter
import numpy

# Retrieve metascore for happy and sad in description
scores_happy = metacritic[metacritic['description'].str.contains("happy")].metascore
scores_sad = metacritic[metacritic['description'].str.contains("sad")].metascore

# Plot into buckets
bins = numpy.linspace(0, 100, 10)
pyplot.title("Comparison histograms with /sad/ and /happy/ key-words in discription field of Movies from Metacritic 2000-2022")
pyplot.xlabel('Metascore')
pyplot.ylabel('Number of Movies')
pyplot.hist (scores_happy, bins, alpha=0.5, label='Movies featuring Happy')
pyplot.hist (scores_sad, bins, alpha=0.5, label='Movies featuring Sad')

pyplot.legend (loc='upper right')

pyplot.show()

# %% [markdown]
# #### Findings: Number of Movies that have word "sad" in discription more often was reviewed and scored on Metacritics.

# %% [markdown]
# ***
# ### Checking 2000-2020 period for finding any unusual dinamic  by using violinplot
# ***

# %%
# violinplot for user rating distribution vs runtime of all films realeased in 2012
plt.figure(figsize=(40,20), dpi=50)
sns.violinplot(x='year', y='metascore',  data=metacritic, scale='width', inner='quartile', lablesize = 30)
# Decoration
#plt.gca().yaxis.set_major_formatter(format_currency)
plt.title('Metascore distribution on 2000-2022 Movies of Metacritisc', fontsize=45)
plt.xticks(fontsize=30)
plt.yticks(fontsize=20)
plt.show()
#still looking for label frontsize

# %% [markdown]
# ****
# #### Findings: What happend in 2007 and 2009 with metascore range?
# ****

# %% [markdown]
# #### Let's double check it with scoter plot
# ***

# %%
from matplotlib import pyplot
from matplotlib.ticker import FormatStrFormatter

# Set up labels on the axes
pyplot.title('Movies scored by Metacritic for 2000-2020 period)')
pyplot.xlabel('Year')
pyplot.ylabel('Number of movies')

# Count movies measured by metacritic by year and plot the results
df = metacritic['year'].groupby(metacritic.year).agg ('count')
pyplot.plot(df,'*')
pyplot.show()

# %% [markdown]
# ***
# #### Findings: There is so small amoount of movies on Metacritic in 2007 and 2009 - why? - I checked Metacritic web-page - there is 467 movies for 2007 and 404 movies for 2009 with very wide spread of metacritic score. Same as for other years, probably my regex just didn't catch all movies! Scatter plot and violinplot poved that.
# ***
